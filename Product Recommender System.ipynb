# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame 
import nltk

from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from scipy.spatial.distance import cosine
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

import re
import string
from wordcloud import WordCloud, STOPWORDS
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("reviewsWithHeader.csv")

# %%
print(df.columns)
print(df.shape)
# Out:
# Index([u'asin', u'overall', u'reviewText', u'reviewTime', u'reviewerID',
#        u'reviewerName', u'summary', u'unixReviewTime', u'HelpfulnessNumerator',
#        u'HelpfulnessDenominator'],
#       dtype='object')
# (477179, 10)

# %% [markdown]
# ### Product based CF

# %%
count = df.groupby("asin", as_index=False).count()
mean = df.groupby("asin", as_index=False).mean()

dfMerged = pd.merge(df, count, how='right', on=['asin'])
dfMerged
# Out:
#               asin  overall_x  \
# 0       7806397051          1
# 1       7806397051          3
# 2       7806397051          4
# 3       7806397051          2
# 4       7806397051          3
# 5       7806397051          5
# 6       7806397051          1
# 7       7806397051          2
# 8       9759091062          2
# 9       9759091062          3
# 10      9759091062          3
# 11      9759091062          1
# 12      9759091062          5
# 13      9759091062          1
# 14      9759091062          5
# 15      9759091062          2
# 16      9759091062          5
# 17      9759091062          4
# 18      9759091062          3
# 19      9788072216          5
# 20      9788072216          5
# 21      9788072216          5
# 22      9788072216          5
# 23      9788072216          5
# 24      9790790961          5
# 25      9790790961          3
# 26      9790790961          5
# 27      9790790961          5
# 28      9790790961          5
# 29      9790790961          3
# ...            ...        ...
# 477149  B00KA602SY          5
# 477150  B00KCWMG5S          2
# 477151  B00KCWMG5S          4
# 477152  B00KCWMG5S          3
# 477153  B00KCWMG5S          1
# 477154  B00KCWMG5S          2
# 477155  B00KF9180W          5
# 477156  B00KF9180W          5
# 477157  B00KF9180W          5
# 477158  B00KF9180W          5
# 477159  B00KF9180W          4
# 477160  B00KF9180W          5
# 477161  B00KF9180W          5
# 477162  B00KF9180W          5
# 477163  B00KF9180W          5
# 477164  B00KF9180W          4
# 477165  B00KGCLROK          2
# 477166  B00KGCLROK          5
# 477167  B00KGCLROK          5
# 477168  B00KGCLROK          5
# 477169  B00KGCLROK          5
# 477170  B00KKXCJQU          5
# 477171  B00KKXCJQU          5
# 477172  B00KKXCJQU          5
# 477173  B00KKXCJQU          5
# 477174  B00KKXCJQU          5
# 477175  B00KKXCJQU          5
# 477176  B00KKXCJQU          5
# 477177  B00KKXCJQU          5
# 477178  B00KKXCJQU          5
#
#                                              reviewText_x reviewTime_x  \
# 0       Very oily and creamy. Not at all what I expect...  01 30, 2014
# 1       This palette was a decent price and I was look...  04 18, 2014
# 2       The texture of this concealer pallet is fantas...   09 6, 2013
# 3       I really can't tell what exactly this thing is...   12 8, 2013
# 4       It was a little smaller than I expected, but t...  10 19, 2013
# 5       I was very happy to get this palette, now I wi...  04 15, 2013
# 6       PLEASE DONT DO IT! this just rachett the palet...  08 16, 2013
# 7       Chalky,Not Pigmented,Wears off easily,Not a Co...   09 4, 2013
# 8       Did nothing for me. Stings when I put it on. I...  07 13, 2014
# 9       I bought this product to get rid of the dark s...  12 27, 2013
# 10      I have mixed feelings about this product. When...  05 20, 2014
# 11      Did nothing for my skin. Used as suggested and...  02 18, 2014
# 12      I bought this product about 3 months ago, I fi...  01 23, 2014
# 13      This gell did nothing at all. I religiously pu...  01 11, 2014
# 14      i got this to get rid of a scar and it did jus...  02 18, 2014
# 15      I used it for anal bleaching and it burned a b...   04 6, 2014
# 16      I order this cream along with their soap. It a...  09 14, 2013
# 17      Good product. Use a little bit on your spot an...  10 18, 2013
# 18      I didn't use it past a week. The reason why is...   11 1, 2013
# 19      I haven't been a big fan of Prada's fragrances...  09 19, 2011
# 20      We gave these as gifts and everyone that recei...  08 10, 2013
# 21      This is the first fragrance by Prada that I lo...  11 28, 2011
# 22      So I got this about a month ago. I had no plan...  05 27, 2012
# 23      This product has a very fruity scent which is ...   02 2, 2013
# 24      I'm very picky when it comes to fragrance. I l...  03 11, 2014
# 25      bright crystals reminds me of Victoria Secrets...  12 19, 2011
# 26      Got this product and I never heard of this so ...   09 8, 2013
# 27      This is a beautiful perfume! Nice, clean scent...   02 2, 2014
# 28      This is the real Versace Bright Crystal fragra...  02 14, 2014
# 29      I love it! and will continue using it but it's...  02 12, 2014
# ...                                                   ...          ...
# 477149  I really like this shirt, very comfortable and...  06 22, 2014
# 477150                                For tiny teenagers.  07 20, 2014
# 477151  Like these pants, 1st time I wore them I rippe...   06 6, 2014
# 477152  I should have waited until I owned the first p...   07 7, 2014
# 477153  Arrived with what looked like a bleach stain o...  06 23, 2014
# 477154  Trying to decide if return or just give away t...   06 5, 2014
# 477155  This is a (2) pack of balcalavas that can be c...  06 27, 2014
# 477156  I really wish I had these a few months ago whe...   06 7, 2014
# 477157  If you are an outdoor person and are outdoors ...   06 4, 2014
# 477158  l  know now just what I am going as for Hallow...  06 16, 2014
# 477159  I go walking a lot in all kinds of weather and...  06 16, 2014
# 477160  This two pack of Balaclavas makes for a very n...   06 9, 2014
# 477161  Well, the first thing I did was try the balacl...  06 13, 2014
# 477162  While balaclavas can be used for a variety of ...  06 13, 2014
# 477163  This is truly a year round product. Here in th...  06 21, 2014
# 477164  Nice material, but not as nice as  silk or mer...   06 9, 2014
# 477165  These were a free sample for review.  I was ex...  06 21, 2014
# 477166  My stepmother does yoga in bare feet or regula...   07 3, 2014
# 477167  These socks are very nicely made and quite com...  06 22, 2014
# 477168  You don&#8217;t have to be a yoga or martial a...   07 5, 2014
# 477169  These are cozy and complements well for yoga. ...  06 24, 2014
# 477170  I really hate my husband's packing system. He ...   06 9, 2014
# 477171  *Disclosure: I was contacted by a rep for Shac...  07 18, 2014
# 477172  This set of travel organizers includes four pi...  06 13, 2014
# 477173  When I pack it looks like a disaster area in a...   06 9, 2014
# 477174  I don't normally go ga-ga over a product very ...  06 24, 2014
# 477175  I've been traveling back and forth to England ...  06 26, 2014
# 477176  These are very nice packing cubes and the 18 x...   06 8, 2014
# 477177  I am on vacation with my family of four and th...   07 7, 2014
# 477178  When I signed up to receive a free set of Shac...  06 23, 2014
#
#           reviewerID_x                                    reviewerName_x  \
# 0       A1YJEY40YUW4SE                                            Andrea
# 1        A60XNB876KYML                                        Jessica H.
# 2       A3G6XNM240RMWA                                             Karen
# 3       A1PQFP6SAJ6D80                                             Norah
# 4       A38FVHZTNQ271F                                         Nova Amor
# 5       A3BTN14HIZET6Z                    S. M. Randall "WildHorseWoman"
# 6       A1Z59RFKN0M5QL                                 tasha "luvely12b"
# 7        AWUO9P6PL1SY8                                     TreMagnifique
# 8       A3LMILRM9OC3SA                                               NaN
# 9       A30IP88QK3YUIO                               Amina Bint Ibraheem
# 10       APBQH4BS48CQO                                           Charmmy
# 11      A3FE8W8UV95U6B                                 Culture C Simmons
# 12      A1EVGDOTGFZOSS                           Jessica "Anarchykisses"
# 13       AP5WTCMP6DTRV                                           Layla B
# 14      A21IM16PQWKVO5                                          mdub9922
# 15      A1TLDR1V4O48PK                     Mickey O Neil "Mickey O Neil"
# 16       A6F8KH0J1AVYA                                            SanBen
# 17       AXPKZA7UZXKTT                                         Shirleyyy
# 18      A2SIAYDK7GG7QA                                      theredtranny
# 19      A1QV5IH6HDRN0L                                          armygirl
# 20      A3UQXHI88S7XAX                                         D. Greene
# 21      A2EK2CJNJUF7OQ                                             Nikki
# 22      A2GWNGQF9SHRE4                             Pholuke "Lepa Shandy"
# 23       ABV67T136UXFQ                                            Sandra
# 24      A2FQZKL2KIZACO                                          Ellie B.
# 25      A312RDWQYLAG7S                                               ltg
# 26      A3TYR1ALBZ2EU9                                       Mananagirl6
# 27       AUYVMLI0CBMYS                                          Shay1234
# 28      A2H0VDRANZMGGX                                         Shoe luva
# 29      A2MZDI3I5AEL74                            Y. Siani "I love nini"
# ...                ...                                               ...
# 477149   ANNHM5C3DX72Q                                    Tracey Simmons
# 477150  A2FENE35P9Z592                                            Amanda
# 477151    AODACROYFBAY                                   Denise M Nelson
# 477152  A3O26N290U3VI0                                            Khouri
# 477153  A15WDJOU6B9FLQ                               L. Atwood "Bothell"
# 477154   AG5N21TGDQWRJ                                       Lori Mohler
# 477155  A12DQZKRKTNF5E                                       Andrea Polk
# 477156  A25C2M3QF9G7OQ                                            Comdet
# 477157   ABDR6IJ93HFIO                                   Daisy "Daisy S"
# 477158  A3BFDEBT5IV4UN  Dianne E. Socci-Tetro "Never Judge a Book by ...
# 477159  A1EVV74UQYVKRY                                           K. Groh
# 477160   ABUE0ALHKWKHC                                              Kiwi
# 477161  A1PI8VBCXXSGC7                                              Lynn
# 477162  A2XX2A4OJCDNLZ                               RatherLiveInKeyWest
# 477163  A2YKWYC3WQJX5J             Shannon Lastowski "Queen of Caffeine"
# 477164  A3UJRNI8UR4871                               Wulfstan "wulfstan"
# 477165  A34BZM6S9L7QI4                       Candy Cane "Is it just me?"
# 477166   A4WEZJOIZIV4U        Chuck Bittner "Disabled comedian & gamer!"
# 477167  A25C2M3QF9G7OQ                                            Comdet
# 477168   ACJT8MUC0LRF0                                         D. Fowler
# 477169  A2NOW4U7W3F7RI                                               rpv
# 477170  A1W415JP5WEAJK                                            Alex S
# 477171   AX05DBU8IRUWY                                        C. Schmidt
# 477172   AEL6CQNQXONBX                                    Cute Chihuahua
# 477173   ACJT8MUC0LRF0                                         D. Fowler
# 477174  A2DG63DN704LOI                                            ESlayd
# 477175  A1EVV74UQYVKRY                                           K. Groh
# 477176  A1UQBFCERIP7VJ                                    Margaret Picky
# 477177  A22CW0ZHY3NJH8                                            Noname
# 477178  A30VWT3R25QAVD          THE-DEADLY-DOG "Living and Loving Life."
#
#                                                 summary_x  unixReviewTime_x  \
# 0                                  Don't waste your money        1391040000
# 1                                             OK Palette!        1397779200
# 2                                           great quality        1378425600
# 3                                  Do not work on my face        1386460800
# 4                                              It's okay.        1382140800
# 5                                      Very nice palette!        1365984000
# 6                                                  smh!!!        1376611200
# 7       Chalky, Not Pigmented, Wears off easily, Not a...        1378252800
# 8             no Lightening, no Brightening,......NOTHING        1405209600
# 9                                             Its alright        1388102400
# 10                                        Mixed feelings.        1400544000
# 11                                                Nothing        1392681600
# 12                                             This works        1390435200
# 13                                           Does nothing        1389398400
# 14                                               it works        1392681600
# 15                                                  burns        1396742400
# 16                                        Did work for me        1379116800
# 17                                              excellent        1382054400
# 18                                            weird smell        1383264000
# 19                                Love the smell of this!        1316390400
# 20                                                  Happy        1376092800
# 21                                              Very good        1322438400
# 22                                       Lurrrrrrrrv.....        1338076800
# 23                                            Great Scent        1359763200
# 24                              Spring Garden in a Bottle        1394496000
# 25                                            fresh smell        1324252800
# 26                                          My new smell!        1378598400
# 27                                        One of my favs!        1391299200
# 28                                           Smells clean        1392336000
# 29       Love the smell but a shame it's not last as long        1392163200
# ...                                                   ...               ...
# 477149                                          Very nice        1403395200
# 477150                                        Teeny pants        1405814400
# 477151                                     fabric is thin        1402012800
# 477152                                  so, this is weird        1404691200
# 477153                                            Stained        1403481600
# 477154                                     just too small        1401926400
# 477155           Quality set with multiple configurations        1403827200
# 477156  I&#8217;m ready for another frigid blast (or a...        1402099200
# 477157  Wonderful for one who is outdoors in cold weat...        1401840000
# 477158  Look Mom I'm a Ninja...No, I'm a Motorcycle  M...        1402876800
# 477159                   Great for Winter or Chilly Walks        1402876800
# 477160        Nice soft protection from the elements.....        1402272000
# 477161  Love that my ears have two layers of protectio...        1402617600
# 477162  Balaclava 2 Pack - Black - Tan - 100% Polyeste...        1402617600
# 477163                     Fits under even a tight helmet        1403308800
# 477164                               Lightweight & useful        1402272000
# 477165                               Wanted to love these        1403308800
# 477166   My stepmother was impressed with the extra grip.        1404345600
# 477167     A bit fussy to get on, but they work very well        1403395200
# 477168  Very nice, comfortable non-slip socks for yoga...        1404518400
# 477169                                              Cozy!        1403568000
# 477170                            Even Husbands can do it        1402272000
# 477171                                    Not for squares        1405641600
# 477172  Can be used for organization but they are grea...        1402617600
# 477173             End of my packing nightmare system ...        1402272000
# 477174     These have literally changed the way I travel!        1403568000
# 477175                       Wonderful for Better Packing        1403740800
# 477176               Convenient, lightweight, and durable        1402185600
# 477177                   Holds Up Well In Real World Test        1404691200
# 477178  Don't Travel? Still Way too Useful for 'Averag...        1403481600
#
#         HelpfulnessNumerator_x  HelpfulnessDenominator_x  overall_y  \
# 0                            3                         4          8
# 1                            1                         1          8
# 2                            0                         1          8
# 3                            2                         2          8
# 4                            0                         0          8
# 5                            1                         2          8
# 6                            1                         3          8
# 7                            0                         1          8
# 8                            0                         0         11
# 9                            0                         0         11
# 10                           0                         0         11
# 11                           0                         0         11
# 12                           0                         1         11
# 13                           0                         0         11
# 14                           0                         1         11
# 15                           0                         0         11
# 16                           2                         4         11
# 17                           2                         4         11
# 18                           0                         1         11
# 19                          24                        24          5
# 20                           0                         0          5
# 21                           1                         1          5
# 22                           2                         4          5
# 23                           0                         0          5
# 24                           1                         1          6
# 25                           0                         1          6
# 26                           0                         0          6
# 27                           0                         1          6
# 28                           1                         2          6
# 29                           0                         0          6
# ...                        ...                       ...        ...
# 477149                       0                         0          6
# 477150                       0                         0          5
# 477151                       2                         2          5
# 477152                       0                         0          5
# 477153                       1                         1          5
# 477154                       0                         0          5
# 477155                       1                         1         10
# 477156                       1                         1         10
# 477157                       2                         3         10
# 477158                       4                         5         10
# 477159                       4                         5         10
# 477160                       4                         7         10
# 477161                       5                         6         10
# 477162                       2                         3         10
# 477163                       7                         8         10
# 477164                       2                         3         10
# 477165                       1                         1          5
# 477166                       0                         0          5
# 477167                       0                         0          5
# 477168                       1                         1          5
# 477169                       0                         0          5
# 477170                       1                         1          9
# 477171                       0                         0          9
# 477172                       2                         2          9
# 477173                       1                         1          9
# 477174                       0                         1          9
# 477175                       0                         0          9
# 477176                       1                         1          9
# 477177                       2                         2          9
# 477178                       0                         1          9
#
#         reviewText_y  reviewTime_y  reviewerID_y  reviewerName_y  summary_y  \
# 0                  8             8             8               8          8
# 1                  8             8             8               8          8
# 2                  8             8             8               8          8
# 3                  8             8             8               8          8
# 4                  8             8             8               8          8
# 5                  8             8             8               8          8
# 6                  8             8             8               8          8
# 7                  8             8             8               8          8
# 8                 11            11            11              10         11
# 9                 11            11            11              10         11
# 10                11            11            11              10         11
# 11                11            11            11              10         11
# 12                11            11            11              10         11
# 13                11            11            11              10         11
# 14                11            11            11              10         11
# 15                11            11            11              10         11
# 16                11            11            11              10         11
# 17                11            11            11              10         11
# 18                11            11            11              10         11
# 19                 5             5             5               5          5
# 20                 5             5             5               5          5
# 21                 5             5             5               5          5
# 22                 5             5             5               5          5
# 23                 5             5             5               5          5
# 24                 6             6             6               6          6
# 25                 6             6             6               6          6
# 26                 6             6             6               6          6
# 27                 6             6             6               6          6
# 28                 6             6             6               6          6
# 29                 6             6             6               6          6
# ...              ...           ...           ...             ...        ...
# 477149             6             6             6               6          6
# 477150             5             5             5               5          5
# 477151             5             5             5               5          5
# 477152             5             5             5               5          5
# 477153             5             5             5               5          5
# 477154             5             5             5               5          5
# 477155            10            10            10              10         10
# 477156            10            10            10              10         10
# 477157            10            10            10              10         10
# 477158            10            10            10              10         10
# 477159            10            10            10              10         10
# 477160            10            10            10              10         10
# 477161            10            10            10              10         10
# 477162            10            10            10              10         10
# 477163            10            10            10              10         10
# 477164            10            10            10              10         10
# 477165             5             5             5               5          5
# 477166             5             5             5               5          5
# 477167             5             5             5               5          5
# 477168             5             5             5               5          5
# 477169             5             5             5               5          5
# 477170             9             9             9               9          9
# 477171             9             9             9               9          9
# 477172             9             9             9               9          9
# 477173             9             9             9               9          9
# 477174             9             9             9               9          9
# 477175             9             9             9               9          9
# 477176             9             9             9               9          9
# 477177             9             9             9               9          9
# 477178             9             9             9               9          9
#
#         unixReviewTime_y  HelpfulnessNumerator_y  HelpfulnessDenominator_y
# 0                      8                       8                         8
# 1                      8                       8                         8
# 2                      8                       8                         8
# 3                      8                       8                         8
# 4                      8                       8                         8
# 5                      8                       8                         8
# 6                      8                       8                         8
# 7                      8                       8                         8
# 8                     11                      11                        11
# 9                     11                      11                        11
# 10                    11                      11                        11
# 11                    11                      11                        11
# 12                    11                      11                        11
# 13                    11                      11                        11
# 14                    11                      11                        11
# 15                    11                      11                        11
# 16                    11                      11                        11
# 17                    11                      11                        11
# 18                    11                      11                        11
# 19                     5                       5                         5
# 20                     5                       5                         5
# 21                     5                       5                         5
# 22                     5                       5                         5
# 23                     5                       5                         5
# 24                     6                       6                         6
# 25                     6                       6                         6
# 26                     6                       6                         6
# 27                     6                       6                         6
# 28                     6                       6                         6
# 29                     6                       6                         6
# ...                  ...                     ...                       ...
# 477149                 6                       6                         6
# 477150                 5                       5                         5
# 477151                 5                       5                         5
# 477152                 5                       5                         5
# 477153                 5                       5                         5
# 477154                 5                       5                         5
# 477155                10                      10                        10
# 477156                10                      10                        10
# 477157                10                      10                        10
# 477158                10                      10                        10
# 477159                10                      10                        10
# 477160                10                      10                        10
# 477161                10                      10                        10
# 477162                10                      10                        10
# 477163                10                      10                        10
# 477164                10                      10                        10
# 477165                 5                       5                         5
# 477166                 5                       5                         5
# 477167                 5                       5                         5
# 477168                 5                       5                         5
# 477169                 5                       5                         5
# 477170                 9                       9                         9
# 477171                 9                       9                         9
# 477172                 9                       9                         9
# 477173                 9                       9                         9
# 477174                 9                       9                         9
# 477175                 9                       9                         9
# 477176                 9                       9                         9
# 477177                 9                       9                         9
# 477178                 9                       9                         9
#
# [477179 rows x 19 columns]

# %%
#rename column
dfMerged["totalReviewers"] = dfMerged["reviewerID_y"]
dfMerged["overallScore"] = dfMerged["overall_x"]
dfMerged["summaryReview"] = dfMerged["summary_x"]

dfNew = dfMerged[['asin','summaryReview','overallScore',"totalReviewers"]]

# %% [markdown]
# Selecting products which have more than 50 reviews

# %%
dfMerged = dfMerged.sort_values(by='totalReviewers', ascending=False)
dfCount = dfMerged[dfMerged.totalReviewers >= 100]
dfCount
# Out:
#               asin  overall_x  \
# 360187  B005LERHD8          5
# 360211  B005LERHD8          5
# 360222  B005LERHD8          3
# 360221  B005LERHD8          4
# 360220  B005LERHD8          4
# 360219  B005LERHD8          5
# 360218  B005LERHD8          4
# 360217  B005LERHD8          5
# 360216  B005LERHD8          2
# 360215  B005LERHD8          4
# 360214  B005LERHD8          3
# 360213  B005LERHD8          5
# 360212  B005LERHD8          5
# 360210  B005LERHD8          4
# 359860  B005LERHD8          3
# 360209  B005LERHD8          4
# 360208  B005LERHD8          5
# 360207  B005LERHD8          4
# 360206  B005LERHD8          5
# 360205  B005LERHD8          5
# 360204  B005LERHD8          5
# 360203  B005LERHD8          5
# 360202  B005LERHD8          4
# 360201  B005LERHD8          5
# 360200  B005LERHD8          5
# 360199  B005LERHD8          5
# 360223  B005LERHD8          4
# 359861  B005LERHD8          5
# 359971  B005LERHD8          5
# 359875  B005LERHD8          5
# ...            ...        ...
# 139644  B006RFZ66K          4
# 139645  B006RFZ66K          5
# 168867  B00AE078YM          2
# 139653  B006RFZ66K          5
# 139658  B006RFZ66K          5
# 139668  B006RFZ66K          3
# 67171   B0020122ZS          5
# 117911  B004Z209HS          4
# 139659  B006RFZ66K          5
# 117909  B004Z209HS          5
# 117908  B004Z209HS          1
# 117907  B004Z209HS          5
# 117906  B004Z209HS          5
# 117905  B004Z209HS          1
# 67170   B0020122ZS          5
# 168924  B00AE078YM          4
# 67169   B0020122ZS          5
# 67168   B0020122ZS          4
# 168888  B00AE078YM          3
# 117910  B004Z209HS          5
# 139667  B006RFZ66K          5
# 139665  B006RFZ66K          5
# 117904  B004Z209HS          5
# 139660  B006RFZ66K          4
# 139661  B006RFZ66K          4
# 139663  B006RFZ66K          2
# 139664  B006RFZ66K          4
# 139662  B006RFZ66K          5
# 139666  B006RFZ66K          4
# 117903  B004Z209HS          5
#
#                                              reviewText_x reviewTime_x  \
# 360187  Love it so cute! Tones of compliments on it. I...   12 2, 2013
# 360211  i was pleased with this purchase! bought it as...  05 30, 2014
# 360222  Breaks very easily but is easily fixed. There ...   07 9, 2014
# 360221                                         Very cute!  07 12, 2014
# 360220  The pendant is very cute but the rhinestones a...  11 29, 2013
# 360219  These are just so cute, I even wear one and ha...  02 11, 2014
# 360218  I was expecting it to be more of a gold tint w...  01 10, 2013
# 360217  I love the length of the chain (which I had pr...   03 1, 2013
# 360216  This was a waste of money. The size was too la...  11 27, 2012
# 360215  It is a really preatty and looks good..came on...  07 14, 2013
# 360214  This necklace is good for the price it was, I ...   02 4, 2013
# 360213  My friends will love them and I might just buy...  12 12, 2013
# 360212  got this as a gift and she loved it. it's a cu...  12 12, 2013
# 360210  I do like this necklace. It looks more brushed...  12 17, 2012
# 359860  I loved the overall look of the necklace but I...   10 3, 2013
# 360209  Thought the chain would be a little longer on ...  10 25, 2013
# 360208  Super cute! The pendant is larger than I expec...  09 21, 2013
# 360207  My chain is long enough, about 32" so I can sl...   07 6, 2013
# 360206  This is a great necklace! It arrived promptly ...  07 22, 2013
# 360205  Let the sellers know I wasn't completely happy...  05 13, 2013
# 360204  Cuter than expected and excellent price, very ...   02 6, 2014
# 360203  I got it for a friend that loves owls! She wea...  10 12, 2013
# 360202  It's cute, in a kitsch-y way. The whole owl lo...  12 26, 2012
# 360201  I love this Vintage Bronze Owl necklace.It is ...   09 7, 2013
# 360200  Everyone really loved getting one from me for ...   01 9, 2014
# 360199  I love this item. Colors arent the same as pic...   01 6, 2014
# 360223  This necklace looks just like they say, it's t...   03 9, 2014
# 359861  This item is cheap like the other reviews say,...  09 27, 2013
# 359971         Beautiful necklaces.  Exactly as pictured.   07 7, 2014
# 359875  This is cute, durable, and a great bargain.Bet...  08 10, 2013
# ...                                                   ...          ...
# 139644  This product doesn't necessarily always work, ...   03 5, 2014
# 139645  I have fairly oily skin, and live in a dusty, ...  02 20, 2013
# 168867  When I first got this, I found the lack of dir...   02 3, 2013
# 139653  You get 24 individually wrapped pore strips. T...  03 28, 2013
# 139658  I use these sparingly only because I don't wan...  12 21, 2012
# 139668  My husband told me to buy this product to take...   09 3, 2013
# 67171   My four-year-old daughter loves this shampoo. ...   03 1, 2013
# 117911  I have thoracic-spine length hair, baby fine, ...  01 15, 2014
# 139659  Biore Deep Cleaning Pore Strips work very well...  02 18, 2013
# 117909  After using this for several days, I must admi...  02 27, 2013
# 117908  I was using 3 types of oil in the past = Premi...  02 14, 2013
# 117907  Pura d'or Argan Oil is the best oil I have eve...  03 10, 2013
# 117906  It's really good for the face and skin!!! I tr...  04 19, 2014
# 117905  I did not have a good experience with this pro...  04 29, 2014
# 67170   Nice subte smell. The coconut smell doesn't re...  02 27, 2013
# 168924  I notice that the huge majority of reviews com...   05 6, 2013
# 67169   My daughter takes her own showers and invariab...  02 21, 2013
# 67168   My daughter is one of those kids who just does...  03 22, 2013
# 168888  I both dislike and like this product.  Is that...  02 17, 2013
# 117910  Pura D'or Pure Organic Argan Oil is a thin oil...  03 16, 2013
# 139667  I've been using these for a long time and they...   12 8, 2013
# 139665  apply on nose and wait long. like 10 min.dont ...   03 8, 2014
# 117904  I use this as my night time facial moisturizer...   04 3, 2014
# 139660  I was advised by a doctor that nose strips sti...   01 2, 2014
# 139661  These are a good little product. They really d...  07 18, 2013
# 139663  I have a lot of whiteheads across the cheek ar...  04 22, 2014
# 139664  Before I go on to give these strips a modest p...   02 6, 2013
# 139662  OMG! It worked!It hurts so much when you pull ...  02 12, 2013
# 139666  This product works by sticking onto the debris...  03 21, 2013
# 117903  I live this oil!!!! I have been using this sol...  05 19, 2014
#
#           reviewerID_x                                    reviewerName_x  \
# 360187  A2XL8GPL563XRK                                            SweetJ
# 360211  A27GAMYJC1U5IC                                      victoria1993
# 360222  A1OHOGJK6QJJZP                                               Zoe
# 360221  A1UJ9PL8CQ5TEQ                                          Zayettcy
# 360220   ARUAJ7VWW3KCI                                          Yuma, AZ
# 360219   APFTQJGB3TFND                                            yblirt
# 360218  A205ZO9KZY2ZD2                                            Winnie
# 360217  A32QDAKOPWYW17                                        WillowJule
# 360216  A19GYKRVE3SP00                            wanderlust "wavelette"
# 360215  A1MO713GHGJXZD                                 V. Rivera "tbell"
# 360214   A5O9USKDYRKVK                                            vmeans
# 360213  A1EHNNMTB08S2P                                        Vincent D.
# 360212  A2NEV5LKP08N01                                  Victoria Engelen
# 360210  A1KCZKMWZGNJMD                                          Vickster
# 359860   ARF5YAIOVLCR1                                            cassie
# 360209  A2DPHKB60JGENT                                          veronica
# 360208  A2G4CKVW5G0K7G                                 Valerie Carpenter
# 360207  A1QM3IBH8SS6VU                                           Valdora
# 360206  A3KHOFC9GOWQY7                                       UrbanFangrl
# 360205  A2SJNS7S6ECGWN                                     Troy Culbreth
# 360204  A3G6DMMDSOMI99                                   Tricia Cartinez
# 360203  A3EAHMM1Y6JTRK                                  Travis Blackwell
# 360202  A1QYE76M7E4ZK4                                             Tracy
# 360201   AZC097NSZCUQ8                                       Tosha Evans
# 360200  A3TWSE14G5PNCW                                            Timpee
# 360199   AD3QONCT8C302                                      Tiffany Gray
# 360223  A23TVM6UI5ULUD                                        Zuri Gandy
# 359861  A2L0XMKSM2E33Y                                             C~A~T
# 359971   AVWYFE169YDNS                                Jeanette Spalliero
# 359875  A1CKPO4W2C5PBK                                         Cheryl H.
# ...                ...                                               ...
# 139644  A3NFE0FB5MN60O                                       Pentel RSVP
# 139645   AKJ3P4XK1KN5Y                                      PhoenixFalls
# 168867   ADY836HK6QSYR                                   ardnam "ardnam"
# 139653  A22CT4ZGGD2FJF                           S. Chang "Steven Chang"
# 139658   AGEVRGK52SKSY                                            texasT
# 139668  A3U5PAYEQSSVJS                                  Yulya Mkhitaryan
# 67171   A231LBC8EGPO5L       OutlawPoet - In a Corrupt Stew "OutlawPoet"
# 117911  A1IKNUYJSRIZ3Z                                   Amber Macintosh
# 139659  A3U5HKDHPYBAK3                                  Thomas P. Troyer
# 117909  A1W415JP5WEAJK                                            Alex S
# 117908  A105TOJ6LTVMBG  Aless "&#34;I came like Water, and like Wind ...
# 117907   AQ8DU6XVA3USJ           Alejandra Vernon "artist & illustrator"
# 117906  A355O3NILU2AXP                                        A. Andrade
# 117905  A1E80M6BKJSMRG                                               NaN
# 67170   A1ODOGXEYECQQ8                                            Nuknuk
# 168924   AHUT55E980RDR                                  Neal C. Reynolds
# 67169    AUV3OR951650C                                         N. Porter
# 67168   A22CW0ZHY3NJH8                                            Noname
# 168888  A2E4R7YISIM4QM                                          E-Cowboy
# 117910  A2D1LPEUCTNT8X                                         Ali Julia
# 139667  A2RPGCVEQ8CQWC                                            Yoanna
# 139665  A28ZCJZ4JCWDJ5                                         virji1988
# 117904  A1G5EJU5Q03MIF                                               NaN
# 139660  A3KQZAIWD70XYD                                            Thy Do
# 139661  A2X0C9E34P5O53                                           TJsweet
# 139663  A3OXB8POGTLMFY                                             Tracy
# 139664   AY6A8KPYCE6B0                                             Tyson
# 139662  A15V46DLC5ODBH                                                to
# 139666   AYPIF2S8P3RZT                                           Vyshtia
# 117903   ADPMGLFFGSAAQ                                               NaN
#
#                                                 summary_x  unixReviewTime_x  \
# 360187                                         Bronze owl        1385942400
# 360211                               what a cute lil owl!        1401408000
# 360222                                              Ehhh.        1404864000
# 360221                                         Four Stars        1405123200
# 360220                                  Great for the $$$        1385683200
# 360219                                               cute        1392076800
# 360218                                            It's ok        1357776000
# 360217                               Absolutely gorgeous!        1362096000
# 360216                      Way too big and unattractive.        1353974400
# 360215                               Nice preatty chain..        1373760000
# 360214                                            Alright        1359936000
# 360213                                         WHO WHO!!!        1386806400
# 360212                                          good gift        1386806400
# 360210                                          Nice item        1355702400
# 359860            It was beautiful but the chain broke :(        1380758400
# 360209                                               Cute        1382659200
# 360208                               Adorable owl pendant        1379721600
# 360207                                          Very cute        1373068800
# 360206                                             Great!        1374451200
# 360205                              Awesome to Deal with.        1368403200
# 360204                                           too cute        1391644800
# 360203                                     Cheap and Chic        1381536000
# 360202                                  NOT FINE JEWELRY!        1356480000
# 360201                                Simply beautiful :)        1378512000
# 360200                                    Amazing looking        1389225600
# 360199                                        my favorite        1388966400
# 360223                                          I love it        1394323200
# 359861                            Cheap but totally cute.        1380240000
# 359971                                         Five Stars        1404691200
# 359875                       Whoo doesn't like a bargain?        1376092800
# ...                                                   ...               ...
# 139644                                                Fun        1393977600
# 139645                                  Fun and Effective        1361318400
# 168867                             confusing instructions        1359849600
# 139653                                    They work well!        1364428800
# 139658        Good Price for Count and Strips work great!        1356048000
# 139668                              Didn't worked for me.        1378166400
# 67171                              Soft and Good Smelling        1362096000
# 117911                        A little goes a lonnnng way        1389744000
# 139659                                   Biore works well        1361145600
# 117909                           A little goes a long way        1361923200
# 117908    Trust me-it's not Pure Argan Oil !!! Beware !!!        1360800000
# 117907                          Morocco's Magnificent Oil        1362873600
# 117906                                       very good!!!        1397865600
# 117905                              Did not work for me..        1398729600
# 67170                     Nice subtle smell.  Shiny hair.        1361923200
# 168924                         Works well for us guys too        1367798400
# 67169               Great idea for grade school children!        1361404800
# 67168                       Helps manages children's hair        1363910400
# 168888                                          Mixed bag        1361059200
# 117910                 Effective, long lasting, unscented        1363392000
# 139667        The way to clean, healthy skin starts here!        1386460800
# 139665                                        works great        1394236800
# 117904                                      Great Product        1396483200
# 139660  Effective yet not protective, pores arent smal...        1388620800
# 139661                             Have always been a fan        1374105600
# 139663                              didn't get whiteheads        1398124800
# 139664                 Easy to use, effective, feels good        1360108800
# 139662                                        Love it !!!        1360627200
# 139666                             Exfoliate before using        1363824000
# 117903                               Great a Moisturizer!        1400457600
#
#         HelpfulnessNumerator_x  HelpfulnessDenominator_x  \
# 360187                       0                         0
# 360211                       0                         0
# 360222                       0                         0
# 360221                       0                         0
# 360220                       1                         1
# 360219                       0                         0
# 360218                       0                         0
# 360217                       0                         0
# 360216                       0                         0
# 360215                       0                         0
# 360214                       0                         0
# 360213                       0                         0
# 360212                       0                         0
# 360210                       1                         1
# 359860                       1                         2
# 360209                       0                         0
# 360208                       2                         3
# 360207                       0                         0
# 360206                       1                         1
# 360205                       0                         0
# 360204                       0                         0
# 360203                       0                         0
# 360202                       0                         0
# 360201                       0                         0
# 360200                       0                         0
# 360199                       0                         0
# 360223                       0                         0
# 359861                       0                         0
# 359971                       0                         0
# 359875                       1                         2
# ...                        ...                       ...
# 139644                       0                         0
# 139645                       1                         1
# 168867                       2                         4
# 139653                       1                         2
# 139658                      44                        57
# 139668                       1                         1
# 67171                        0                         0
# 117911                       3                         5
# 139659                       1                         1
# 117909                       0                         0
# 117908                      15                        56
# 117907                       3                         9
# 117906                       0                         0
# 117905                       2                         8
# 67170                        0                         0
# 168924                       0                         0
# 67169                        1                         2
# 67168                        0                         0
# 168888                       0                         0
# 117910                       0                         0
# 139667                       3                         3
# 139665                       0                         0
# 117904                       0                         1
# 139660                       1                         2
# 139661                       0                         0
# 139663                       0                         0
# 139664                       2                         4
# 139662                       1                         2
# 139666                       1                         2
# 117903                       0                         0
#
#                               ...                          reviewTime_y  \
# 360187                        ...                                   441
# 360211                        ...                                   441
# 360222                        ...                                   441
# 360221                        ...                                   441
# 360220                        ...                                   441
# 360219                        ...                                   441
# 360218                        ...                                   441
# 360217                        ...                                   441
# 360216                        ...                                   441
# 360215                        ...                                   441
# 360214                        ...                                   441
# 360213                        ...                                   441
# 360212                        ...                                   441
# 360210                        ...                                   441
# 359860                        ...                                   441
# 360209                        ...                                   441
# 360208                        ...                                   441
# 360207                        ...                                   441
# 360206                        ...                                   441
# 360205                        ...                                   441
# 360204                        ...                                   441
# 360203                        ...                                   441
# 360202                        ...                                   441
# 360201                        ...                                   441
# 360200                        ...                                   441
# 360199                        ...                                   441
# 360223                        ...                                   441
# 359861                        ...                                   441
# 359971                        ...                                   441
# 359875                        ...                                   441
# ...                           ...                                   ...
# 139644                        ...                                   100
# 139645                        ...                                   100
# 168867                        ...                                   100
# 139653                        ...                                   100
# 139658                        ...                                   100
# 139668                        ...                                   100
# 67171                         ...                                   100
# 117911                        ...                                   100
# 139659                        ...                                   100
# 117909                        ...                                   100
# 117908                        ...                                   100
# 117907                        ...                                   100
# 117906                        ...                                   100
# 117905                        ...                                   100
# 67170                         ...                                   100
# 168924                        ...                                   100
# 67169                         ...                                   100
# 67168                         ...                                   100
# 168888                        ...                                   100
# 117910                        ...                                   100
# 139667                        ...                                   100
# 139665                        ...                                   100
# 117904                        ...                                   100
# 139660                        ...                                   100
# 139661                        ...                                   100
# 139663                        ...                                   100
# 139664                        ...                                   100
# 139662                        ...                                   100
# 139666                        ...                                   100
# 117903                        ...                                   100
#
#         reviewerID_y  reviewerName_y  summary_y  unixReviewTime_y  \
# 360187           441             441        441               441
# 360211           441             441        441               441
# 360222           441             441        441               441
# 360221           441             441        441               441
# 360220           441             441        441               441
# 360219           441             441        441               441
# 360218           441             441        441               441
# 360217           441             441        441               441
# 360216           441             441        441               441
# 360215           441             441        441               441
# 360214           441             441        441               441
# 360213           441             441        441               441
# 360212           441             441        441               441
# 360210           441             441        441               441
# 359860           441             441        441               441
# 360209           441             441        441               441
# 360208           441             441        441               441
# 360207           441             441        441               441
# 360206           441             441        441               441
# 360205           441             441        441               441
# 360204           441             441        441               441
# 360203           441             441        441               441
# 360202           441             441        441               441
# 360201           441             441        441               441
# 360200           441             441        441               441
# 360199           441             441        441               441
# 360223           441             441        441               441
# 359861           441             441        441               441
# 359971           441             441        441               441
# 359875           441             441        441               441
# ...              ...             ...        ...               ...
# 139644           100             100        100               100
# 139645           100             100        100               100
# 168867           100             100        100               100
# 139653           100             100        100               100
# 139658           100             100        100               100
# 139668           100             100        100               100
# 67171            100             100        100               100
# 117911           100              97        100               100
# 139659           100             100        100               100
# 117909           100              97        100               100
# 117908           100              97        100               100
# 117907           100              97        100               100
# 117906           100              97        100               100
# 117905           100              97        100               100
# 67170            100             100        100               100
# 168924           100             100        100               100
# 67169            100             100        100               100
# 67168            100             100        100               100
# 168888           100             100        100               100
# 117910           100              97        100               100
# 139667           100             100        100               100
# 139665           100             100        100               100
# 117904           100              97        100               100
# 139660           100             100        100               100
# 139661           100             100        100               100
# 139663           100             100        100               100
# 139664           100             100        100               100
# 139662           100             100        100               100
# 139666           100             100        100               100
# 117903           100              97        100               100
#
#         HelpfulnessNumerator_y  HelpfulnessDenominator_y  totalReviewers  \
# 360187                     441                       441             441
# 360211                     441                       441             441
# 360222                     441                       441             441
# 360221                     441                       441             441
# 360220                     441                       441             441
# 360219                     441                       441             441
# 360218                     441                       441             441
# 360217                     441                       441             441
# 360216                     441                       441             441
# 360215                     441                       441             441
# 360214                     441                       441             441
# 360213                     441                       441             441
# 360212                     441                       441             441
# 360210                     441                       441             441
# 359860                     441                       441             441
# 360209                     441                       441             441
# 360208                     441                       441             441
# 360207                     441                       441             441
# 360206                     441                       441             441
# 360205                     441                       441             441
# 360204                     441                       441             441
# 360203                     441                       441             441
# 360202                     441                       441             441
# 360201                     441                       441             441
# 360200                     441                       441             441
# 360199                     441                       441             441
# 360223                     441                       441             441
# 359861                     441                       441             441
# 359971                     441                       441             441
# 359875                     441                       441             441
# ...                        ...                       ...             ...
# 139644                     100                       100             100
# 139645                     100                       100             100
# 168867                     100                       100             100
# 139653                     100                       100             100
# 139658                     100                       100             100
# 139668                     100                       100             100
# 67171                      100                       100             100
# 117911                     100                       100             100
# 139659                     100                       100             100
# 117909                     100                       100             100
# 117908                     100                       100             100
# 117907                     100                       100             100
# 117906                     100                       100             100
# 117905                     100                       100             100
# 67170                      100                       100             100
# 168924                     100                       100             100
# 67169                      100                       100             100
# 67168                      100                       100             100
# 168888                     100                       100             100
# 117910                     100                       100             100
# 139667                     100                       100             100
# 139665                     100                       100             100
# 117904                     100                       100             100
# 139660                     100                       100             100
# 139661                     100                       100             100
# 139663                     100                       100             100
# 139664                     100                       100             100
# 139662                     100                       100             100
# 139666                     100                       100             100
# 117903                     100                       100             100
#
#         overallScore                                      summaryReview
# 360187             5                                         Bronze owl
# 360211             5                               what a cute lil owl!
# 360222             3                                              Ehhh.
# 360221             4                                         Four Stars
# 360220             4                                  Great for the $$$
# 360219             5                                               cute
# 360218             4                                            It's ok
# 360217             5                               Absolutely gorgeous!
# 360216             2                      Way too big and unattractive.
# 360215             4                               Nice preatty chain..
# 360214             3                                            Alright
# 360213             5                                         WHO WHO!!!
# 360212             5                                          good gift
# 360210             4                                          Nice item
# 359860             3            It was beautiful but the chain broke :(
# 360209             4                                               Cute
# 360208             5                               Adorable owl pendant
# 360207             4                                          Very cute
# 360206             5                                             Great!
# 360205             5                              Awesome to Deal with.
# 360204             5                                           too cute
# 360203             5                                     Cheap and Chic
# 360202             4                                  NOT FINE JEWELRY!
# 360201             5                                Simply beautiful :)
# 360200             5                                    Amazing looking
# 360199             5                                        my favorite
# 360223             4                                          I love it
# 359861             5                            Cheap but totally cute.
# 359971             5                                         Five Stars
# 359875             5                       Whoo doesn't like a bargain?
# ...              ...                                                ...
# 139644             4                                                Fun
# 139645             5                                  Fun and Effective
# 168867             2                             confusing instructions
# 139653             5                                    They work well!
# 139658             5        Good Price for Count and Strips work great!
# 139668             3                              Didn't worked for me.
# 67171              5                             Soft and Good Smelling
# 117911             4                        A little goes a lonnnng way
# 139659             5                                   Biore works well
# 117909             5                           A little goes a long way
# 117908             1    Trust me-it's not Pure Argan Oil !!! Beware !!!
# 117907             5                          Morocco's Magnificent Oil
# 117906             5                                       very good!!!
# 117905             1                              Did not work for me..
# 67170              5                    Nice subtle smell.  Shiny hair.
# 168924             4                         Works well for us guys too
# 67169              5              Great idea for grade school children!
# 67168              4                      Helps manages children's hair
# 168888             3                                          Mixed bag
# 117910             5                 Effective, long lasting, unscented
# 139667             5        The way to clean, healthy skin starts here!
# 139665             5                                        works great
# 117904             5                                      Great Product
# 139660             4  Effective yet not protective, pores arent smal...
# 139661             4                             Have always been a fan
# 139663             2                              didn't get whiteheads
# 139664             4                 Easy to use, effective, feels good
# 139662             5                                        Love it !!!
# 139666             4                             Exfoliate before using
# 117903             5                               Great a Moisturizer!
#
# [39731 rows x 22 columns]

# %% [markdown]
# ### Grouping all the summary Reviews by product ID

# %%
dfProductReview = df.groupby("asin", as_index=False).mean()
ProductReviewSummary = dfCount.groupby("asin")["summaryReview"].apply(list)
ProductReviewSummary = pd.DataFrame(ProductReviewSummary)
ProductReviewSummary.to_csv("ProductReviewSummary.csv")

# %%
dfProductReview
# Out:
#              asin   overall  unixReviewTime  HelpfulnessNumerator  \
# 0      0000031887  4.608696    1.370064e+09              0.391304
# 1      0123456479  4.166667    1.382947e+09              0.333333
# 2      1608299953  4.307692    1.307637e+09             27.769231
# 3      1617160377  4.625000    1.321078e+09              4.625000
# 4      7806397051  2.625000    1.382087e+09              1.000000
# 5      9759091062  3.090909    1.390930e+09              0.363636
# 6      9788072216  5.000000    1.342552e+09              5.400000
# 7      9790790961  4.333333    1.378858e+09              0.333333
# 8      9790794231  3.600000    1.298212e+09              0.600000
# 9      B00001W0KA  4.625000    1.349492e+09              0.250000
# 10     B00001WRHJ  3.500000    1.353586e+09              0.333333
# 11     B00004SR8W  4.666667    1.346782e+09              2.583333
# 12     B00004SR8Z  4.545455    1.363828e+09              1.545455
# 13     B00004SR9P  4.000000    1.340091e+09              4.000000
# 14     B00004TMFE  3.318182    1.360714e+09              1.090909
# 15     B00004TUBL  4.347826    1.348952e+09              1.739130
# 16     B00004TUBV  4.400000    1.367505e+09              0.000000
# 17     B00004U1J2  3.923077    1.370537e+09              0.384615
# 18     B00004U9UY  4.538462    1.358500e+09              0.230769
# 19     B00004U9V2  4.714286    1.385202e+09              0.000000
# 20     B000050B6U  4.313725    1.364569e+09              2.019608
# 21     B000051SEN  4.500000    1.302880e+09              2.750000
# 22     B000051SEP  4.333333    1.249819e+09              3.666667
# 23     B000052WY7  4.000000    1.377924e+09              0.400000
# 24     B000052WYD  3.680000    1.369642e+09              1.480000
# 25     B000052WYL  4.086957    1.376499e+09              0.869565
# 26     B000052WYN  3.838710    1.373403e+09              0.612903
# 27     B000052X9G  2.800000    1.349274e+09              1.200000
# 28     B000052XIA  4.857143    1.313724e+09              1.714286
# 29     B000052XW5  4.333333    1.352333e+09              0.583333
# ...           ...       ...             ...                   ...
# 35093  B00KLA4INE  5.000000    1.404283e+09              0.545455
# 35094  B00KLJDYL2  5.000000    1.403712e+09              0.500000
# 35095  B00KLZO2JE  4.941176    1.404305e+09              0.352941
# 35096  B00KNIL36E  4.962963    1.405350e+09              0.000000
# 35097  B00KNJOLSA  4.909091    1.404621e+09              0.181818
# 35098  B00KPKIV8I  4.600000    1.404593e+09              0.133333
# 35099  B00KQ4PEBU  4.642857    1.405024e+09              0.464286
# 35100  B00KQBR9FM  4.745098    1.404754e+09              0.421569
# 35101  B00KQVTX06  4.813953    1.405244e+09              0.000000
# 35102  B00KTAJAIY  4.785714    1.404086e+09              0.071429
# 35103  B00KTLBDYM  4.086957    1.404815e+09              0.478261
# 35104  B00KTLBEEQ  4.515152    1.404940e+09              0.666667
# 35105  B00KTP8Q1G  5.000000    1.404475e+09              1.166667
# 35106  B00KVE7R0Q  5.000000    1.405901e+09              0.000000
# 35107  B00KVO2JWC  4.857143    1.405370e+09              0.285714
# 35108  B00KWE08Q0  4.900000    1.405192e+09              0.900000
# 35109  B00KXG8JF4  4.950000    1.405028e+09              1.250000
# 35110  B00L0C529Q  4.846154    1.403575e+09              1.076923
# 35111  B00L2K53BS  4.800000    1.404847e+09              0.600000
# 35112  B00L2KVF9W  5.000000    1.405166e+09              0.333333
# 35113  B00L3K91OW  5.000000    1.404886e+09              0.125000
# 35114  B00L3LB0IG  5.000000    1.404585e+09              0.076923
# 35115  B00L3LBUGI  5.000000    1.404718e+09              0.187500
# 35116  B00L5BXG36  5.000000    1.405555e+09              2.428571
# 35117  B00L5JHZJO  3.400000    1.401728e+09              7.800000
# 35118  B00L5KTZ0K  5.000000    1.405014e+09              0.000000
# 35119  B00L6Q3BH6  4.400000    1.400734e+09              3.000000
# 35120  B00LCEROA2  5.000000    1.404643e+09              0.111111
# 35121  B00LG63DOM  4.800000    1.405823e+09              0.800000
# 35122  B00LLPT4HI  5.000000    1.405580e+09              0.285714
#
#        HelpfulnessDenominator
# 0                    0.478261
# 1                    0.666667
# 2                   30.230769
# 3                    5.062500
# 4                    1.750000
# 5                    1.000000
# 6                    5.800000
# 7                    0.833333
# 8                    4.800000
# 9                    0.500000
# 10                   0.666667
# 11                   2.666667
# 12                   1.818182
# 13                   4.250000
# 14                   1.500000
# 15                   2.130435
# 16                   0.000000
# 17                   0.615385
# 18                   0.230769
# 19                   0.142857
# 20                   2.235294
# 21                   3.000000
# 22                   4.833333
# 23                   0.600000
# 24                   1.800000
# 25                   1.086957
# 26                   0.709677
# 27                   4.600000
# 28                   4.428571
# 29                   0.750000
# ...                       ...
# 35093                0.545455
# 35094                0.500000
# 35095                0.823529
# 35096                0.000000
# 35097                0.181818
# 35098                0.133333
# 35099                0.500000
# 35100                0.598039
# 35101                0.000000
# 35102                0.071429
# 35103                0.478261
# 35104                0.696970
# 35105                3.166667
# 35106                0.000000
# 35107                0.571429
# 35108                0.900000
# 35109                1.500000
# 35110                1.076923
# 35111                0.800000
# 35112                0.333333
# 35113                0.187500
# 35114                0.076923
# 35115                0.187500
# 35116                2.428571
# 35117                8.100000
# 35118                0.133333
# 35119                3.000000
# 35120                0.111111
# 35121                0.800000
# 35122                0.428571
#
# [35123 rows x 5 columns]

# %% [markdown]
# ### create dataframe with certain columns

# %%
df3 = pd.read_csv("ProductReviewSummary.csv")
df3 = pd.merge(df3, dfProductReview, on="asin", how='inner')

# %%
df3 = df3[['asin','summaryReview','overall']]

# %% [markdown]
# ### Text Cleaning - Summary column

# %%
#function for tokenizing summary
regEx = re.compile('[^a-z]+')
def cleanReviews(reviewText):
    reviewText = reviewText.lower()
    reviewText = regEx.sub(' ', reviewText).strip()
    return reviewText

# %%
#reset index and drop duplicate rows
df3["summaryClean"] = df3["summaryReview"].apply(cleanReviews)
df3 = df3.drop_duplicates(['overall'], keep='last')
df3 = df3.reset_index()

# %%
reviews = df3["summaryClean"] 
countVector = CountVectorizer(max_features = 300, stop_words='english') 
transformedReviews = countVector.fit_transform(reviews) 

dfReviews = DataFrame(transformedReviews.A, columns=countVector.get_feature_names())
dfReviews = dfReviews.astype(int)

# %%
#save 
dfReviews.to_csv("dfReviews.csv")

# %%
# First let's create a dataset called X
X = np.array(dfReviews)
 # create train and test
tpercent = 0.9
tsize = int(np.floor(tpercent * len(dfReviews)))
dfReviews_train = X[:tsize]
dfReviews_test = X[tsize:]
#len of train and test
lentrain = len(dfReviews_train)
lentest = len(dfReviews_test)

# %%
# KNN classifier to find similar products
print(lentrain)
print(lentest)
# Out:
# 234
# 27

# %%
neighbor = NearestNeighbors(n_neighbors=3, algorithm='ball_tree').fit(dfReviews_train)

# Let's find the k-neighbors of each point in object X. To do that we call the kneighbors() function on object X.
distances, indices = neighbor.kneighbors(dfReviews_train)

# %%
#find most related products
for i in range(lentest):
    a = neighbor.kneighbors([dfReviews_test[i]])
    related_product_list = a[1]

    first_related_product = [item[0] for item in related_product_list]
    first_related_product = str(first_related_product).strip('[]')
    first_related_product = int(first_related_product)
    second_related_product = [item[1] for item in related_product_list]
    second_related_product = str(second_related_product).strip('[]')
    second_related_product = int(second_related_product)
    
    print ("Based on product reviews, for ", df3["asin"][lentrain + i] ," average rating is ",df3["overall"][lentrain + i])
    print ("The first similar product is ", df3["asin"][first_related_product] ," average rating is ",df3["overall"][first_related_product])
    print ("The second similar product is ", df3["asin"][second_related_product] ," average rating is ",df3["overall"][second_related_product])
    print ("-----------------------------------------------------------")
# Out:
# ('Based on product reviews, for ', 'B00AO4EMKQ', ' average rating is ', 4.2857142857142856)
# ('The first similar product is ', 'B005TI7LHS', ' average rating is ', 4.1391304347826088)
# ('The second similar product is ', 'B00AO4EL34', ' average rating is ', 4.1909090909090905)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00AWLB9G6', ' average rating is ', 4.3962264150943398)
# ('The first similar product is ', 'B00AO4E9MC', ' average rating is ', 4.339130434782609)
# ('The second similar product is ', 'B00AE078YM', ' average rating is ', 3.7799999999999998)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00AWLB9I4', ' average rating is ', 4.2079207920792081)
# ('The first similar product is ', 'B00AE078YM', ' average rating is ', 3.7799999999999998)
# ('The second similar product is ', 'B00AO4E9MC', ' average rating is ', 4.339130434782609)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00BNB3A0W', ' average rating is ', 3.4414414414414414)
# ('The first similar product is ', 'B009T47YZ2', ' average rating is ', 3.4545454545454546)
# ('The second similar product is ', 'B004Z1CZDK', ' average rating is ', 3.1923076923076925)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00C7DYBX0', ' average rating is ', 4.0980392156862742)
# ('The first similar product is ', 'B0090UJFYI', ' average rating is ', 4.2454545454545451)
# ('The second similar product is ', 'B004LUZ956', ' average rating is ', 4.024390243902439)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00C8YCFU4', ' average rating is ', 4.66412213740458)
# ('The first similar product is ', 'B000F63TW0', ' average rating is ', 4.3384615384615381)
# ('The second similar product is ', 'B0089JVDPK', ' average rating is ', 4.3931623931623935)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00CIBCJ62', ' average rating is ', 4.2164179104477615)
# ('The first similar product is ', 'B004R1II48', ' average rating is ', 4.0555555555555554)
# ('The second similar product is ', 'B005C5FP9Y', ' average rating is ', 4.1946902654867255)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00CKGB85I', ' average rating is ', 4.0666666666666664)
# ('The first similar product is ', 'B004R1II48', ' average rating is ', 4.0555555555555554)
# ('The second similar product is ', 'B0074T7TY0', ' average rating is ', 4.2554744525547443)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00CN47GXA', ' average rating is ', 3.4634146341463414)
# ('The first similar product is ', 'B007WAU1VY', ' average rating is ', 3.5514705882352939)
# ('The second similar product is ', 'B007WAEBPQ', ' average rating is ', 4.333333333333333)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00D1MR8YU', ' average rating is ', 3.8373983739837398)
# ('The first similar product is ', 'B004R1II48', ' average rating is ', 4.0555555555555554)
# ('The second similar product is ', 'B0007QCOTM', ' average rating is ', 4.6568627450980395)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00DMWQK0W', ' average rating is ', 4.2980769230769234)
# ('The first similar product is ', 'B008RUOCJU', ' average rating is ', 3.9736842105263159)
# ('The second similar product is ', 'B009T47YZ2', ' average rating is ', 3.4545454545454546)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00DMWQOYY', ' average rating is ', 4.119718309859155)
# ('The first similar product is ', 'B008RUOCJU', ' average rating is ', 3.9736842105263159)
# ('The second similar product is ', 'B0067GUM2W', ' average rating is ', 4.1748633879781423)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00DNQIIE8', ' average rating is ', 4.2287581699346406)
# ('The first similar product is ', 'B0078FXHNM', ' average rating is ', 4.26056338028169)
# ('The second similar product is ', 'B0067GUM2W', ' average rating is ', 4.1748633879781423)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00DQYNS3I', ' average rating is ', 4.5263157894736841)
# ('The first similar product is ', 'B003YBHF82', ' average rating is ', 4.21)
# ('The second similar product is ', 'B0008172S4', ' average rating is ', 4.2666666666666666)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00G5WO2VK', ' average rating is ', 4.7565217391304344)
# ('The first similar product is ', 'B007Q0WW0S', ' average rating is ', 4.568965517241379)
# ('The second similar product is ', 'B004Z209HS', ' average rating is ', 4.3899999999999997)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00GFBWWWC', ' average rating is ', 4.693548387096774)
# ('The first similar product is ', 'B0000CC64W', ' average rating is ', 4.314685314685315)
# ('The second similar product is ', 'B003MJ7Z0O', ' average rating is ', 4.0606060606060606)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00H93NJLS', ' average rating is ', 4.7928571428571427)
# ('The first similar product is ', 'B004Z209HS', ' average rating is ', 4.3899999999999997)
# ('The second similar product is ', 'B007Q0WW0S', ' average rating is ', 4.568965517241379)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00HJD8NLY', ' average rating is ', 4.8851351351351351)
# ('The first similar product is ', 'B0000CC64W', ' average rating is ', 4.314685314685315)
# ('The second similar product is ', 'B003MJ7Z0O', ' average rating is ', 4.0606060606060606)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00I6CRX04', ' average rating is ', 4.2214765100671139)
# ('The first similar product is ', 'B00604MSSC', ' average rating is ', 4.1619047619047622)
# ('The second similar product is ', 'B001V3TVEQ', ' average rating is ', 3.9166666666666665)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00IBS9QC6', ' average rating is ', 4.9153846153846157)
# ('The first similar product is ', 'B000F63TW0', ' average rating is ', 4.3384615384615381)
# ('The second similar product is ', 'B003MJ7Z0O', ' average rating is ', 4.0606060606060606)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00IP42FBA', ' average rating is ', 4.8717948717948714)
# ('The first similar product is ', 'B004Z209HS', ' average rating is ', 4.3899999999999997)
# ('The second similar product is ', 'B0013TM9UQ', ' average rating is ', 4.4710743801652892)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00JJVG6HC', ' average rating is ', 4.8092105263157894)
# ('The first similar product is ', 'B007RTR89S', ' average rating is ', 3.8811881188118811)
# ('The second similar product is ', 'B00AO4E9E0', ' average rating is ', 4.3883495145631066)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00KAL5JAU', ' average rating is ', 4.7611940298507465)
# ('The first similar product is ', 'B00AO4E9MC', ' average rating is ', 4.339130434782609)
# ('The second similar product is ', 'B007RTR8T8', ' average rating is ', 4.1078431372549016)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00KCFAZTE', ' average rating is ', 4.7592592592592595)
# ('The first similar product is ', 'B00AO4EKSU', ' average rating is ', 4.0956521739130434)
# ('The second similar product is ', 'B0007W1R58', ' average rating is ', 4.4272727272727277)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00KHGIK54', ' average rating is ', 4.8320610687022905)
# ('The first similar product is ', 'B0000CC64W', ' average rating is ', 4.314685314685315)
# ('The second similar product is ', 'B003MJ7Z0O', ' average rating is ', 4.0606060606060606)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00KHH2VOY', ' average rating is ', 4.8770491803278686)
# ('The first similar product is ', 'B002TSA90M', ' average rating is ', 4.4521739130434783)
# ('The second similar product is ', 'B00AE07IEM', ' average rating is ', 4.2752293577981648)
# -----------------------------------------------------------
# ('Based on product reviews, for ', 'B00KQBR9FM', ' average rating is ', 4.7450980392156863)
# ('The first similar product is ', 'B00AO4EKSU', ' average rating is ', 4.0956521739130434)
# ('The second similar product is ', 'B0030HKJ8I', ' average rating is ', 4.3241379310344827)
# -----------------------------------------------------------

# %%
print ("Based on product reviews, for ", df3["asin"][260] ," average rating is ",df3["overall"][260])
print ("The first similar product is ", df3["asin"][first_related_product] ," average rating is ",df3["overall"][first_related_product])
print ("The second similar product is ", df3["asin"][second_related_product] ," average rating is ",df3["overall"][second_related_product])
print ("-----------------------------------------------------------")
# Out:
# ('Based on product reviews, for ', 'B00KQBR9FM', ' average rating is ', 4.7450980392156863)
# ('The first similar product is ', 'B00AO4EKSU', ' average rating is ', 4.0956521739130434)
# ('The second similar product is ', 'B0030HKJ8I', ' average rating is ', 4.3241379310344827)
# -----------------------------------------------------------

# %% [markdown]
# ### Predicting Review Score

# %%
df5_train_target = df3["overall"][:lentrain]
df5_test_target = df3["overall"][lentrain:lentrain+lentest]
df5_train_target = df5_train_target.astype(int)
df5_test_target = df5_test_target.astype(int)

n_neighbors = 3
knnclf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knnclf.fit(dfReviews_train, df5_train_target)
knnpreds_test = knnclf.predict(dfReviews_test)

print(classification_report(df5_test_target, knnpreds_test))
# Out:
#              precision    recall  f1-score   support
#
#           3       0.33      0.33      0.33         3
#           4       0.92      0.92      0.92        24
#
# avg / total       0.85      0.85      0.85        27

# %% [markdown]
# ### Accuracy of the model

# %%
print (accuracy_score(df5_test_target, knnpreds_test))
# Out:
# 0.851851851852

# %%
print(mean_squared_error(df5_test_target, knnpreds_test))
# Out:
# 0.148148148148

# %% [markdown]
# ### Predicting Review Score with k = 5

# %%
df5_train_target = df3["overall"][:lentrain]
df5_test_target = df3["overall"][lentrain:lentrain+lentest]
df5_train_target = df5_train_target.astype(int)
df5_test_target = df5_test_target.astype(int)

n_neighbors = 5
knnclf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knnclf.fit(dfReviews_train, df5_train_target)
knnpreds_test = knnclf.predict(dfReviews_test)
#print (knnpreds_test)

print(classification_report(df5_test_target, knnpreds_test))
# Out:
#              precision    recall  f1-score   support
#
#           3       1.00      0.33      0.50         3
#           4       0.92      1.00      0.96        24
#
# avg / total       0.93      0.93      0.91        27

# %%
print (accuracy_score(df5_test_target, knnpreds_test))
# Out:
# 0.925925925926

# %%
print(mean_squared_error(df5_test_target, knnpreds_test))
# Out:
# 0.0740740740741
